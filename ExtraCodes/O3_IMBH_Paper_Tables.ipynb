# %%
import pylab, pandas as pd, numpy
from IPython.display import display, Math, Latex

# %% [markdown]
# ### Table I

# %%
events = ['GW190521',
         'S200114f',
         'S200214br']

GPS_Time = ['1242442967.5', 
            '1263002916.2',
            '1265755544.5',]

PyCBC_IFAR = [726.65, #https://ldas-jobs.gw.iucaa.in/~koustav.chandra/o3/production/imbh/a2_INITIAL/7._open_box_result/7.02_loudest_events_followup/#A51
              1.159e-3, #https://ldas-jobs.ligo-wa.caltech.edu/~veronica.villa/o3/production/imbh/a8_INITIAL/7._open_box_result/#A2
              numpy.nan] # Not found in box 8
              
PyCBC_FAP = [1.027e-3,
             1,
             numpy.nan]

# The cWB and GstLAL results are obtained from the table 
# https://git.ligo.org/publications/O3/o3-cbc-burst-imbh/-/wikis/IMBH-candidate-events

cWB_IFAR = [4903.45, 
           17.77,
           7.61]
           
cWB_FAP = [1.116e-4,
           0.0303,
           6.94e-2]

GstLAL_IFAR = [518.2,
               2.78e-5,
               numpy.nan]

GstLAL_FAP = [0.001685,
              1,
              numpy.nan]

table_1 = pd.DataFrame()

table_1['Events'] = events
table_1['GPS Time'] = GPS_Time

table_1['PyCBC IFAR'] = PyCBC_IFAR
table_1['PyCBC FAR'] = 1/table_1['PyCBC IFAR']
table_1['PyCBC FAP'] = PyCBC_FAP

table_1['cWB IFAR'] = cWB_IFAR
table_1['cWB FAR'] = 1/table_1['cWB IFAR']
table_1['cWB FAP'] = cWB_FAP

table_1['GstLAL IFAR'] = GstLAL_IFAR
table_1['GstLAL FAR'] = 1/table_1['GstLAL IFAR']
table_1['GstLAL FAP'] = GstLAL_FAP

table_1['min FAP'] =  table_1[['cWB FAP','PyCBC FAP', 'GstLAL FAP']].min(axis=1)
trials_factor = 3
table_1['Combined FAP'] = 1 - numpy.power((1- table_1['min FAP']),trials_factor)
table_1['Detectors'] = ['HLV', 'HLV', 'HL']
table_1
# Out:
#       Events      GPS Time  PyCBC IFAR  ...   min FAP  Combined FAP  Detectors
# 0   GW190521  1242442967.5  726.650000  ...  0.000112      0.000335        HLV
# 1   S200114f  1263002916.2    0.001159  ...  0.030300      0.088174        HLV
# 2  S200214br  1265755544.5         NaN  ...  0.069400      0.194085         HL
#
# [3 rows x 14 columns]

# %%
def f1(x):
  if numpy.isnan(x):
    return 'N/A'
  elif x < 1:
    x = "{:.1E}".format(x)
    a = str(x).replace('E-0', r'\times 10^{-') + '}' 
    return '$'+str(a) + '$'
  elif x > 1:
    x = "{:.1E}".format(x)
    a = str(x).replace('E+0', r'\times 10^{+') + '}' 
    return '$'+str(a) + '$'
headers = ['Events', 
           'GPS Time', 
           'cWB FAR',
           'PyCBC FAR', 
           'GstLAL FAR',
           'Combined FAP']

# %%
print(table_1.to_latex(index=False,
                       columns=headers, 
                       formatters={'cWB FAR' : f1,
                                   'PyCBC FAR': f1,
                                   'GstLAL FAR' : f1,
                                   'Combined FAP':f1},
                       escape=False))
# Out:
# \begin{tabular}{llrrrr}
# \toprule
#     Events &      GPS Time &             cWB FAR &           PyCBC FAR &          GstLAL FAR &        Combined FAP \\
# \midrule
#   GW190521 &  1242442967.5 & $2.0\times 10^{-4}$ & $1.4\times 10^{-3}$ & $1.9\times 10^{-3}$ & $3.3\times 10^{-4}$ \\
#   S200114f &  1263002916.2 & $5.6\times 10^{-2}$ & $8.6\times 10^{+2}$ & $3.6\times 10^{+4}$ & $8.8\times 10^{-2}$ \\
#  S200214br &  1265755544.5 & $1.3\times 10^{-1}$ &                 N/A &                 N/A & $1.9\times 10^{-1}$ \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Table II

# %%
event = ['GW190408\_181802',
         'GW190413\_052954',
         'GW190413\_134308',
         'GW190421\_213856',
         'GW190503\_185404',
         'GW190512\_180714',
         'GW190513\_205428',
         'GW190514\_065416',
         'GW190517\_055101',
         'GW190519\_153544',
         'GW190521',
         'GW190521\_074359',
         'GW190602\_175927',
         'GW190701\_203306',
         'GW190706\_222641',
         'GW190727\_060333',
         'GW190731\_140936',
         'GW190803\_022701',
         'GW190828\_063405',
         'GW190915\_235702',
         'GW190929\_012149']

cWB_FAR = [9.5e-4,
           numpy.nan,
           numpy.nan,
           3.0e-1,
           1.8e-3,
           8.8e-3,
           numpy.nan,
           numpy.nan,
           8.0e-3,
           3.061e-4,
           2.039e-4,
           1.0e-4,
           1.5e-2,
           0.32,
           1.0e-3,
           8.8e-2,
           numpy.nan,
           numpy.nan,
           9.6e-4,
           1.0e-4,
           numpy.nan
           ]

PyCBC_FAR = [2.5e-5,
             numpy.nan,
             numpy.nan,
             1.9,
             3.7e-2,
             3.8e-5,
             3.7e-4,
             numpy.nan,
             1.8e-2,
             1.8e-5,
             1.1,
             1.8e-5,
             numpy.nan,
             numpy.nan,
             6.7e-5,
             3.5e-5,
             numpy.nan,
             numpy.nan,
             1.0e-5,
             8.6e-4,
             numpy.nan
             ] 

PyCBC_BBH_FAR = [7.9e-5,
                 7.2e-2,
                 4.4e-2,
                 6.6e-3,
                 7.9e-5,
                 5.7e-5,
                 5.7e-5,
                 0.53,
                 5.7e-5,
                 5.7e-5,
                 numpy.nan,
                 5.7e-5,
                 1.5e-2,
                 numpy.nan,
                 4.6e-5,
                 3.7e-5,
                 0.28,
                 2.7e-2,
                 3.3e-5,
                 3.3e-5,
                 numpy.nan
                 ]

PyCBC_IMBH_FAR = [1.6e-2,
                  0.56,
                  0.14,
                  6.1e-3,
                  2.5e-3,
                  39.87,
                  5.0e-2,
                  1.12,
                  8.7e-4,
                  1.1e-4,
                  1.4e-3,
                  2.3e-5,
                  1.1e-3,
                  1.93e-4,
                  1.1e-4,
                  1.2e-4,
                  0.64,
                  0.17,
                  7.0e-5,
                  3.8e-4,
                  0.31]

GstLAL_FAR = [1.0e-5,
              numpy.nan,
              0.38,
              7.7e-4,
              1.0e-5,
              1.0e-5,
              1.0e-5,
              numpy.nan,
              9.6e-4,
              1.0e-5,
              1.2e-3,
              1.0e-5,
              1.1e-5,
              1.1e-2,
              1.0e-5,
              1.0e-5,
              0.21,
              3.2e-2,
              1.0e-5,
              1.0e-5,
              2.0e-2]

GstLAL_IMBH_FAR = [1.0e-5,
                   5.4e3,
                   1.2e3,
                   1.8,
                   0.2,
                   1.0e-5,
                   0.2,
                   7.6e2,
                   2.7e-2,
                   4.0e-3,
                   1.9e-3,
                   1.0e-5,
                   1.0e-5,
                   3.8e-2,
                   2.4e-3,
                   4.5e-4,
                   2.1,
                   3.0,
                   1.0e-5,
                   0.5,
                   2.9e1]

# %%
table_2 = pd.DataFrame()
table_2['Event'] = event
table_2['cWB FAR'] = cWB_FAR
table_2['PyCBC FAR'] = PyCBC_FAR
table_2['PyCBC BBH FAR'] = PyCBC_BBH_FAR
table_2['PyCBC IMBH FAR'] = PyCBC_IMBH_FAR
table_2['GstLAL FAR'] = GstLAL_FAR
table_2['GstLAL IMBH FAR'] = GstLAL_IMBH_FAR

PyCBC_Ta = 0.747
cWB_Ta = 0.547
GstLAL_Ta = 0.874
table_2['PyCBC FAP'] = 1-numpy.exp(-table_2['PyCBC IMBH FAR']*PyCBC_Ta)
table_2['cWB FAP'] = 1-numpy.exp(-table_2['cWB FAR']*cWB_Ta)
table_2['GstLAL FAP'] = 1-numpy.exp(-table_2['GstLAL IMBH FAR']*GstLAL_Ta)

table_2['min FAP'] =  table_2[['cWB FAP','PyCBC FAP', 'GstLAL FAP']].min(axis=1)
trials_factor = 3
table_2['Combined FAP'] = 1 - numpy.power((1- table_2['min FAP']),trials_factor)

# %%
table_2
# Out:
#                Event   cWB FAR  PyCBC FAR  ...  GstLAL FAP   min FAP  Combined FAP
# 0   GW190408\_181802  0.000950   0.000025  ...    0.000009  0.000009      0.000026
# 1   GW190413\_052954       NaN        NaN  ...    1.000000  0.341848      0.714913
# 2   GW190413\_134308       NaN        NaN  ...    1.000000  0.099297      0.269291
# 3   GW190421\_213856  0.300000   1.900000  ...    0.792619  0.004546      0.013577
# 4   GW190503\_185404  0.001800   0.037000  ...    0.160375  0.000984      0.002949
# 5   GW190512\_180714  0.008800   0.000038  ...    0.000009  0.000009      0.000026
# 6   GW190513\_205428       NaN   0.000370  ...    0.160375  0.036661      0.106000
# 7   GW190514\_065416       NaN        NaN  ...    1.000000  0.566836      0.918725
# 8   GW190517\_055101  0.008000   0.018000  ...    0.023322  0.000650      0.001948
# 9   GW190519\_153544  0.000306   0.000018  ...    0.003490  0.000082      0.000246
# 10          GW190521  0.000204   1.100000  ...    0.001659  0.000112      0.000335
# 11  GW190521\_074359  0.000100   0.000018  ...    0.000009  0.000009      0.000026
# 12  GW190602\_175927  0.015000        NaN  ...    0.000009  0.000009      0.000026
# 13  GW190701\_203306  0.320000        NaN  ...    0.032667  0.000144      0.000432
# 14  GW190706\_222641  0.001000   0.000067  ...    0.002095  0.000082      0.000246
# 15  GW190727\_060333  0.088000   0.000035  ...    0.000393  0.000090      0.000269
# 16  GW190731\_140936       NaN        NaN  ...    0.840450  0.380027      0.761704
# 17  GW190803\_022701       NaN        NaN  ...    0.927343  0.119258      0.316802
# 18  GW190828\_063405  0.000960   0.000010  ...    0.000009  0.000009      0.000026
# 19  GW190915\_235702  0.000100   0.000860  ...    0.354029  0.000055      0.000164
# 20  GW190929\_012149       NaN        NaN  ...    1.000000  0.206713      0.500781
#
# [21 rows x 12 columns]

# %%
def f2(x):
  if (x == 2.5e-5 or x ==1.8e-5 
      or x == 1.0e-5 or x == 7.9e-5 
      or x == 5.7e-5 or x == 3.3e-5 
      or x == 1.0e-4 or x == 1.0e-3 
      or x == 9.6e-4):
    x = "{:.1E}".format(x)
    a = str(x).replace('E-0', r'\times 10^{-') + '}' 
    return '$<'+str(a) + '$'
  elif numpy.isnan(x):
    return '-'
  elif (x < 1):
    x = "{:.1E}".format(x)
    a = str(x).replace('E-0', r'\times 10^{-') + '}'
    return '$'+str(a) + '$'
  elif (x > 1):
    x = "{:.1E}".format(x)
    a = str(x).replace('E+0', r'\times 10^{+') + '}'
    return '$'+str(a) + '$'
    
def f3(x):
  if x < 1.0e-4:
    return r'$ < 1.0 \times 10^{-4}$'
  elif (x < 1):
    x = "{:.1E}".format(x)
    a = str(x).replace('E-0', r'\times 10^{-') + '}'
    return '$'+str(a) + '$'
  elif (x > 1):
    x = "{:.1E}".format(x)
    a = str(x).replace('E+0', r'\times 10^{+') + '}'
    return '$'+str(a) + '$'

# %%
headers = ['Event', 
           'cWB FAR', 
           'PyCBC FAR',
           'PyCBC BBH FAR',
           'PyCBC IMBH FAR',
           'GstLAL FAR',
           'GstLAL IMBH FAR',
           'Combined FAP']

# %%
print(table_2.to_latex(index=False,
                       columns=headers, 
                       formatters={'cWB FAR' : f2,
                                   'PyCBC FAR': f2,
                                   'PyCBC BBH FAR' : f2,
                                   'PyCBC IMBH FAR': f2,
                                   'GstLAL FAR' : f2,
                                   'GstLAL IMBH FAR' : f2,
                                   'Combined FAP': f3},
                       escape=False))
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
#             Event &              cWB FAR &            PyCBC FAR &        PyCBC BBH FAR &      PyCBC IMBH FAR &           GstLAL FAR &      GstLAL IMBH FAR &            Combined FAP \\
# \midrule
#  GW190408\_181802 &  $9.5\times 10^{-4}$ & $<2.5\times 10^{-5}$ & $<7.9\times 10^{-5}$ & $1.6\times 10^{-2}$ & $<1.0\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $ < 1.0 \times 10^{-4}$ \\
#  GW190413\_052954 &                    - &                    - &  $7.2\times 10^{-2}$ & $5.6\times 10^{-1}$ &                    - &  $5.4\times 10^{+3}$ &     $7.1\times 10^{-1}$ \\
#  GW190413\_134308 &                    - &                    - &  $4.4\times 10^{-2}$ & $1.4\times 10^{-1}$ &  $3.8\times 10^{-1}$ &  $1.2\times 10^{+3}$ &     $2.7\times 10^{-1}$ \\
#  GW190421\_213856 &  $3.0\times 10^{-1}$ &  $1.9\times 10^{+0}$ &  $6.6\times 10^{-3}$ & $6.1\times 10^{-3}$ &  $7.7\times 10^{-4}$ &  $1.8\times 10^{+0}$ &     $1.4\times 10^{-2}$ \\
#  GW190503\_185404 &  $1.8\times 10^{-3}$ &  $3.7\times 10^{-2}$ & $<7.9\times 10^{-5}$ & $2.5\times 10^{-3}$ & $<1.0\times 10^{-5}$ &  $2.0\times 10^{-1}$ &     $2.9\times 10^{-3}$ \\
#  GW190512\_180714 &  $8.8\times 10^{-3}$ &  $3.8\times 10^{-5}$ & $<5.7\times 10^{-5}$ & $4.0\times 10^{+1}$ & $<1.0\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $ < 1.0 \times 10^{-4}$ \\
#  GW190513\_205428 &                    - &  $3.7\times 10^{-4}$ & $<5.7\times 10^{-5}$ & $5.0\times 10^{-2}$ & $<1.0\times 10^{-5}$ &  $2.0\times 10^{-1}$ &     $1.1\times 10^{-1}$ \\
#  GW190514\_065416 &                    - &                    - &  $5.3\times 10^{-1}$ & $1.1\times 10^{+0}$ &                    - &  $7.6\times 10^{+2}$ &     $9.2\times 10^{-1}$ \\
#  GW190517\_055101 &  $8.0\times 10^{-3}$ &  $1.8\times 10^{-2}$ & $<5.7\times 10^{-5}$ & $8.7\times 10^{-4}$ & $<9.6\times 10^{-4}$ &  $2.7\times 10^{-2}$ &     $1.9\times 10^{-3}$ \\
#  GW190519\_153544 &  $3.1\times 10^{-4}$ & $<1.8\times 10^{-5}$ & $<5.7\times 10^{-5}$ & $1.1\times 10^{-4}$ & $<1.0\times 10^{-5}$ &  $4.0\times 10^{-3}$ &     $2.5\times 10^{-4}$ \\
#          GW190521 &  $2.0\times 10^{-4}$ &  $1.1\times 10^{+0}$ &                    - & $1.4\times 10^{-3}$ &  $1.2\times 10^{-3}$ &  $1.9\times 10^{-3}$ &     $3.3\times 10^{-4}$ \\
#  GW190521\_074359 & $<1.0\times 10^{-4}$ & $<1.8\times 10^{-5}$ & $<5.7\times 10^{-5}$ & $2.3\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $ < 1.0 \times 10^{-4}$ \\
#  GW190602\_175927 &  $1.5\times 10^{-2}$ &                    - &  $1.5\times 10^{-2}$ & $1.1\times 10^{-3}$ &  $1.1\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $ < 1.0 \times 10^{-4}$ \\
#  GW190701\_203306 &  $3.2\times 10^{-1}$ &                    - &                    - & $1.9\times 10^{-4}$ &  $1.1\times 10^{-2}$ &  $3.8\times 10^{-2}$ &     $4.3\times 10^{-4}$ \\
#  GW190706\_222641 & $<1.0\times 10^{-3}$ &  $6.7\times 10^{-5}$ &  $4.6\times 10^{-5}$ & $1.1\times 10^{-4}$ & $<1.0\times 10^{-5}$ &  $2.4\times 10^{-3}$ &     $2.5\times 10^{-4}$ \\
#  GW190727\_060333 &  $8.8\times 10^{-2}$ &  $3.5\times 10^{-5}$ &  $3.7\times 10^{-5}$ & $1.2\times 10^{-4}$ & $<1.0\times 10^{-5}$ &  $4.5\times 10^{-4}$ &     $2.7\times 10^{-4}$ \\
#  GW190731\_140936 &                    - &                    - &  $2.8\times 10^{-1}$ & $6.4\times 10^{-1}$ &  $2.1\times 10^{-1}$ &  $2.1\times 10^{+0}$ &     $7.6\times 10^{-1}$ \\
#  GW190803\_022701 &                    - &                    - &  $2.7\times 10^{-2}$ & $1.7\times 10^{-1}$ &  $3.2\times 10^{-2}$ &  $3.0\times 10^{+0}$ &     $3.2\times 10^{-1}$ \\
#  GW190828\_063405 & $<9.6\times 10^{-4}$ & $<1.0\times 10^{-5}$ & $<3.3\times 10^{-5}$ & $7.0\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $<1.0\times 10^{-5}$ & $ < 1.0 \times 10^{-4}$ \\
#  GW190915\_235702 & $<1.0\times 10^{-4}$ &  $8.6\times 10^{-4}$ & $<3.3\times 10^{-5}$ & $3.8\times 10^{-4}$ & $<1.0\times 10^{-5}$ &  $5.0\times 10^{-1}$ &     $1.6\times 10^{-4}$ \\
#  GW190929\_012149 &                    - &                    - &                    - & $3.1\times 10^{-1}$ &  $2.0\times 10^{-2}$ &  $2.9\times 10^{+1}$ &     $5.0\times 10^{-1}$ \\
# \bottomrule
# \end{tabular}
